# %%
import os

#only use GPU 0 
#os.environ["CUDA_VISIBLE_DEVICES"]="0"

# Force CPU use
os.environ["CUDA_VISIBLE_DEVICES"]="1"

#import tensorrt
import tensorflow as tf
# Out:
# 2023-05-26 15:19:37.188487: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-26 15:19:37.755038: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import sys
from pathlib import Path
import os
import re
import pickle
import numpy as np



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import cv2

import matplotlib.font_manager as fm
from matplotlib.collections import QuadMesh

from sklearn.model_selection import train_test_split
from skimage.transform import resize
from skimage.io import imread
import sklearn.metrics
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import plot_model
from keras_preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

import os

HOME = Path('/home/peregrin/Desktop')

data_base_dir = HOME / 'CNN-main/Input'
Path_to_folder = HOME / 'CNN-main'



print('Collecting data from {}:'.format(str(data_base_dir)))
train_files = list((data_base_dir / 'Raw_images').glob('*.png'))


mask_files = list()
for _f in train_files:
    _mf = data_base_dir / str(_f).replace("raw", "segmentation").replace("Raw_images", "segmentation_images")
    
    mask_files.append(_mf)
    

print('  … collected {} samples.'.format(len(train_files)))


os.chdir(Path_to_folder)
df_variable_information = pd.read_csv('Finished_annotations_depth_information.csv')

#HERE YOU LOOP THROUGH LIKE BEFORE AND GET THE LABEL!
def assign_class(size):
    if size == '0-5 mm':
        return 0
    elif size == '6-9 mm':
        return 1
    elif size == '10-19 mm':
        return 2
    else:
        return 3
    

label_files = list()
patient_id_list = list()
polyp_num_list = list()




for _f in train_files: 
    filename = os.path.basename(_f)
    parts = filename.split("_")
    patient_id = int(parts[1])
    P_x = parts[2]
    polyp_num = int(P_x[1:])
    patient_id_list.append(patient_id)
    polyp_num_list.append(polyp_num)
    
    
    filter_condition = (df_variable_information['Patient ID'] == patient_id) & (df_variable_information['Polyp'] == polyp_num)
    #label_OC = df_variable_information.loc[filter_condition, 'OC Morphology'].values[0]
    label_value = df_variable_information.loc[filter_condition, 'class'].values[0]
    label_value = assign_class(label_value)
    
    label_files.append(label_value)
    
    
    #Variables we want included in the numerical/categorical dataframe
    
    
    

print(len(label_files), len(train_files), len(mask_files))

# Splitting the data set
df = pd.DataFrame(data={"filename": [str(_f) for _f in train_files], 'mask': [str(_f) for _f in mask_files], 'label': [str(_f) for _f in label_files],
                        'Patient ID': [_f for _f in patient_id_list],'Polyp': [_f for _f in polyp_num_list]})
df_train, df_test = train_test_split(df, test_size=0.1)
df_train, df_val = train_test_split(df_train, test_size=0.2)
# Out:
# Collecting data from /home/peregrin/Desktop/CNN-main/Input:
#   … collected 235 samples.
# 235 235 235

# %%
IMG_CHANNELS = 3
IMG_WIDTH = 526
IMG_HEIGHT = 526
epochs = 15                    
batchSIZE = 3
Patience = 10                   
learning_rate = 1e-5
augment_training_data = False    # Performs flipping and rotations by 90°

train_generator_args = dict(rotation_range=0.5,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')

# %%
def train_generator(data_frame, batch_size, aug_dict,
                    image_color_mode="rgb",
                    mask_color_mode="grayscale",
                    image_save_prefix="image",
                    mask_save_prefix="mask",
                    save_to_dir=None,
                    target_size=(IMG_CHANNELS, IMG_WIDTH),
                    seed=1,
                    augment:bool=False):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col="filename",
        y_col = "label",
        class_mode="sparse",
        color_mode=image_color_mode,
        target_size=target_size,
        batch_size=batch_size,
        shuffle = False,
        save_to_dir=save_to_dir,
        save_prefix=image_save_prefix,
        seed=seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col="mask",
        class_mode=None,
        color_mode=mask_color_mode,
        target_size=target_size,
        batch_size=batch_size,
        shuffle = False,
        save_to_dir=save_to_dir,
        save_prefix=mask_save_prefix,
        seed=seed)

    #train_gen = zip(image_generator, mask_generator)
    train_gen = image_generator

    for (img, label) in image_generator:
        #print('Got label', label, ' -- ', img[0, 125, 125,0])
        for _i, _m in adjust_data(img, label, augment):
            yield (_i, _m)


def rescale_data(img):
    """ Rescale images to have float channels \in [0, 1], boolean masks.

        TODO: this is hard coded and could be automated based on the input format and range.
    """
    img = img / 255


    return (img)


def augment_data(img, label):
    """ Data augmentation by rotation and flipping.

        TODO: This is rather messy and inefficient right now, just straight forward for testing. Clean this up later. :-)
              Actually, the whole data loading process doesn't seem to be optimised.
              https://www.tensorflow.org/api_docs/python/tf/image
              https://www.tensorflow.org/tutorials/images/data_augmentation

        TODO: we could rotate images by random angles, as we would only loose a bit of the circular shape.
              This might actually help to decrease border effects, as the border to the black background is
              then shifting slightly. But might also make things worse for the same reason. :-)
              https://docs.opencv.org/4.x/dd/d52/tutorial_js_geometric_transformations.html
    """
    images = [img]
    #masks = [mask]

    flipped_img = tf.image.flip_up_down(img)
    images.append(flipped_img)
    #masks.append(flipped_mask)

    for i in range(1, 4):
        images.append(tf.image.rot90(img, i))
        #masks.append(tf.image.rot90(mask, i))
        images.append(tf.image.rot90(flipped_img, i))
        #masks.append(tf.image.rot90(flipped_mask, i))

    return zip(images, 8 * [label])


def adjust_data(img, label, augment:bool):
    """ Perform image value scaling and augmentation """
    img = rescale_data(img)

    if not augment:
        return zip([img], [label])

    return augment_data(img, label)



train_gen = train_generator(df_train, batchSIZE, train_generator_args,
                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                            augment=augment_training_data)

#x_img, x_mask= next(train_gen)

valid_gen = train_generator(df_val, batchSIZE,
                            dict(),
                            target_size=(IMG_HEIGHT, IMG_WIDTH))

test_gen = train_generator(df_test, batchSIZE,
                            dict(),
                            target_size=(IMG_HEIGHT, IMG_WIDTH))

#x_img_val, x_mask_val= next(valid_gen)

#%% data variables input in batches
#batchSIZE = 3

# %%
# import the necessary packages
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model


def create_mlp(dim, regress=False):
    # define our MLP network
    model = Sequential()
    model.add(Dense(10, input_dim=dim, activation="relu"))
    model.add(Dense(10, input_dim=dim, activation="relu"))
    model.add(Dense(8, input_dim=dim, activation="relu"))
    model.add(Dense(6, input_dim=dim, activation="relu"))
    model.add(Dense(4, activation="softmax"))
    # check to see if the regression node should be added
    if regress:
        model.add(Dense(1, activation="linear"))
    # return our model
    return model


def create_cnn(width, height, depth, filters=(64, 64, 128, 128, 256), regress=False):
    inputShape = (height, width, depth)
    inputs = Input(shape=inputShape)
    x = inputs
    x = Conv2D(64, (3,3), padding="same")(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)
    x = Conv2D(64, (3,3), padding="same")(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(128, (3,3), padding="same")(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)
    x = Conv2D(128, (3,3), padding="same")(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)
    x = Conv2D(256, (3,3), padding="same")(x)
    x = Activation("relu")(x)
    x = Flatten()(x)
    x = Dense(256)(x)
    x = Activation("relu")(x)
    x = Dropout(0.25)(x)
    x = Dense(128)(x)
    x = Activation("relu")(x)
    x = Dropout(0.25)(x)
    x = Dense(64)(x)
    x = Activation("relu")(x)
    x = Dense(4)(x)
    x = Activation("softmax")(x)
    # check to see if the regression node should be added
    if regress:
        x = Dense(1, activation="linear")(x)
    # construct the CNN
    model = Model(inputs, x)
    # return the CNN
    return model




from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import concatenate
import numpy as np
import argparse
import locale
import os

# %% [markdown]
# # All 10 variables

# %%
def your_generator_batched(attr, img, repeat=True):
    # We need to provide data for multiple epochs
    while repeat:
        combined = zip(attr, img)
        for row, (xtrain_var, ytrain_label) in combined:
            yield {"dense_5_input": row,
                   "input_1": xtrain_var}, \
                  ytrain_label

# %%
#%% Creating df with variables for both train, val and test
df_Columns = df_variable_information[['Patient ID', 'Polyp', 'Contour area', 'Contour circumference', 'Largest diameter', 'Smallest diameter', 'Box area', 'Box circumference', 'Fill ratio', 'ratio_surroundings', 'ratio_segmentation', 'ratio_segmentation_surround']]


df_train_variables = pd.merge(df_train, df_Columns, on = ['Patient ID', 'Polyp'], how = 'inner')
df_train_variables = df_train_variables.drop(columns = ['filename', 'mask', 'Patient ID', 'Polyp'])

df_val_variables = pd.merge(df_val, df_Columns, on = ['Patient ID', 'Polyp'], how = 'inner')
df_val_variables = df_val_variables.drop(columns = ['filename', 'mask', 'Patient ID', 'Polyp'])

df_test_variables = pd.merge(df_test, df_Columns, on = ['Patient ID', 'Polyp'], how = 'inner')
df_test_variables = df_test_variables.drop(columns = ['filename', 'mask', 'Patient ID', 'Polyp'])


df_train_variables_labels = np.array(df_train_variables['label'])
df_train_variables = df_train_variables.drop(columns = ['label'])
dataset_train = tf.data.Dataset.from_tensor_slices((df_train_variables.values, df_train_variables_labels))


df_val_variables_labels = np.array(df_val_variables['label'])
df_val_variables = df_val_variables.drop(columns = ['label'])
dataset_val = tf.data.Dataset.from_tensor_slices((df_val_variables.values, df_val_variables_labels))



df_test_variables_labels = np.array(df_test_variables['label'])
df_test_variables = df_test_variables.drop(columns = ['label'])
dataset_test = tf.data.Dataset.from_tensor_slices((df_test_variables.values, df_test_variables_labels))

xval_var, yval_label = next(dataset_val.as_numpy_iterator())
# Out:
# 2023-05-26 15:21:03.053974: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-05-26 15:21:03.054000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: took
# 2023-05-26 15:21:03.054005: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: took
# 2023-05-26 15:21:03.054101: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 530.30.2
# 2023-05-26 15:21:03.054120: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 530.30.2
# 2023-05-26 15:21:03.054125: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 530.30.2
# 2023-05-26 15:21:03.073779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype string and shape [43]
# 	 [[{{node Placeholder/_1}}]]

# %%
# create the MLP and CNN models
mlp = create_mlp(xval_var.shape[0], regress=False) #
cnn = create_cnn(526, 526, 3, regress=False)

combinedInput = concatenate([mlp.output, cnn.output])

x = Dense(4, activation="softmax")(combinedInput)

model = Model(inputs=[mlp.input, cnn.input], outputs=x)


dataset_train = tf.data.Dataset.from_tensor_slices(df_train_variables)
dataset_train = dataset_train.batch(batchSIZE)

dataset_val = tf.data.Dataset.from_tensor_slices(df_val_variables)
dataset_val = dataset_val.batch(batchSIZE)
#batchSIZE = len(df_val)

dataset_test = tf.data.Dataset.from_tensor_slices(df_test_variables)
dataset_test = dataset_val.batch(batchSIZE)

# %%
gen = your_generator_batched(dataset_train, train_gen)
val = your_generator_batched(dataset_val, valid_gen)
test = your_generator_batched(dataset_test, test_gen)

# %%
from tensorflow.keras.optimizers.legacy import Adam
opt = Adam(learning_rate=1e-3, decay=1e-3 / 200)
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt, metrics=['accuracy'])
# train the model
print("[INFO] training model...")
hist = model.fit(gen,
	#x=[xtrain_var, x_img], y=x_mask,
    steps_per_epoch=len(df_train) / batchSIZE,
    #steps_per_epoch=len(dataset_train) / batchSIZE,
    validation_data=val,
    validation_steps=len(df_val) / batchSIZE,
	epochs=30, batch_size=batchSIZE)

fig = plt.figure(figsize = plt.figaspect(0.3))
fig.suptitle("Loss and accuracy for CNN-MLP model")
        
ax = fig.add_subplot(1,2,1)
ax.plot(hist.history['loss'], label='Train loss')
ax.plot(hist.history['val_loss'], label = 'Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()


ax = fig.add_subplot(1,2,2)
ax.plot(hist.history['accuracy'], label='Train accuracy')
ax.plot(hist.history['val_accuracy'], label = 'Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


plt.show()
# Out:
# [INFO] training model...
# Epoch 1/30
# 2023-05-26 15:21:32.648838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 56/56 [==============================] - ETA: 0s - loss: 1.3975 - accuracy: 0.2262Found 43 validated image filenames belonging to 4 classes.
# Found 43 validated image filenames.
# 2023-05-26 15:22:15.826159: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [43,10]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-26 15:22:15.864258: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 56/56 [==============================] - 45s 792ms/step - loss: 1.3975 - accuracy: 0.2262 - val_loss: 1.2832 - val_accuracy: 0.3953
# Epoch 2/30
# 56/56 [==============================] - 45s 795ms/step - loss: 1.3672 - accuracy: 0.4405 - val_loss: 1.2811 - val_accuracy: 0.3953
# Epoch 3/30
# 56/56 [==============================] - 44s 792ms/step - loss: 1.3480 - accuracy: 0.4405 - val_loss: 1.2828 - val_accuracy: 0.3953
# Epoch 4/30
# 56/56 [==============================] - 44s 794ms/step - loss: 1.3345 - accuracy: 0.4405 - val_loss: 1.2866 - val_accuracy: 0.3953
# Epoch 5/30
# 56/56 [==============================] - 44s 794ms/step - loss: 1.3250 - accuracy: 0.4405 - val_loss: 1.2914 - val_accuracy: 0.3953
# Epoch 6/30
# 56/56 [==============================] - 44s 778ms/step - loss: 1.3181 - accuracy: 0.4405 - val_loss: 1.2965 - val_accuracy: 0.3953
# Epoch 26/30
# 56/56 [==============================] - 43s 776ms/step - loss: 1.3004 - accuracy: 0.4405 - val_loss: 1.3422 - val_accuracy: 0.3953
# Epoch 27/30
# 56/56 [==============================] - 44s 777ms/step - loss: 1.3004 - accuracy: 0.4405 - val_loss: 1.3426 - val_accuracy: 0.3953
# Epoch 28/30
# 56/56 [==============================] - 43s 773ms/step - loss: 1.3004 - accuracy: 0.4405 - val_loss: 1.3430 - val_accuracy: 0.3953
# Epoch 29/30
# 56/56 [==============================] - 43s 772ms/step - loss: 1.3004 - accuracy: 0.4405 - val_loss: 1.3432 - val_accuracy: 0.3953
# Epoch 30/30
# 56/56 [==============================] - 43s 772ms/step - loss: 1.3004 - accuracy: 0.4405 - val_loss: 1.3435 - val_accuracy: 0.3953

# %%
# Only smallest and largest diameter

# %%
def your_generator_batched(attr, img, repeat=True):
    # We need to provide data for multiple epochs
    while repeat:
        combined = zip(attr, img)
        for row, (xtrain_var, ytrain_label) in combined:
            yield {"dense_25_input": row,
                   "input_3": xtrain_var}, \
                  ytrain_label

# %%
#%% Creating df with variables for both train, val and test
df_Columns = df_variable_information[['Patient ID', 'Polyp',  'Largest diameter', 'Smallest diameter']]


df_train_variables = pd.merge(df_train, df_Columns, on = ['Patient ID', 'Polyp'], how = 'inner')
df_train_variables = df_train_variables.drop(columns = ['filename', 'mask', 'Patient ID', 'Polyp'])

df_val_variables = pd.merge(df_val, df_Columns, on = ['Patient ID', 'Polyp'], how = 'inner')
df_val_variables = df_val_variables.drop(columns = ['filename', 'mask', 'Patient ID', 'Polyp'])

df_test_variables = pd.merge(df_test, df_Columns, on = ['Patient ID', 'Polyp'], how = 'inner')
df_test_variables = df_test_variables.drop(columns = ['filename', 'mask', 'Patient ID', 'Polyp'])


df_train_variables_labels = np.array(df_train_variables['label'])
df_train_variables = df_train_variables.drop(columns = ['label'])
dataset_train = tf.data.Dataset.from_tensor_slices((df_train_variables.values, df_train_variables_labels))


df_val_variables_labels = np.array(df_val_variables['label'])
df_val_variables = df_val_variables.drop(columns = ['label'])
dataset_val = tf.data.Dataset.from_tensor_slices((df_val_variables.values, df_val_variables_labels))




df_test_variables_labels = np.array(df_test_variables['label'])
df_test_variables = df_test_variables.drop(columns = ['label'])
dataset_test = tf.data.Dataset.from_tensor_slices((df_test_variables.values, df_test_variables_labels))


xval_var, yval_label = next(dataset_val.as_numpy_iterator())
# Out:
# 2023-05-26 15:45:31.168923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype string and shape [43]
# 	 [[{{node Placeholder/_1}}]]

# %%
# create the MLP and CNN models
mlp = create_mlp(xval_var.shape[0], regress=False) #
cnn = create_cnn(526, 526, 3, regress=False)

combinedInput = concatenate([mlp.output, cnn.output])

x = Dense(4, activation="softmax")(combinedInput)

model = Model(inputs=[mlp.input, cnn.input], outputs=x)


dataset_train = tf.data.Dataset.from_tensor_slices(df_train_variables)
dataset_train = dataset_train.batch(batchSIZE)

dataset_val = tf.data.Dataset.from_tensor_slices(df_val_variables)
dataset_val = dataset_val.batch(batchSIZE)
#batchSIZE = len(df_val)

dataset_test = tf.data.Dataset.from_tensor_slices(df_test_variables)
dataset_test = dataset_val.batch(batchSIZE)

# %%
gen = your_generator_batched(dataset_train, train_gen)
val = your_generator_batched(dataset_val, valid_gen)
test = your_generator_batched(dataset_test, test_gen)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer='adam', metrics=['accuracy'])
# train the model
print("[INFO] training model...")
hist = model.fit(gen,
	#x=[xtrain_var, x_img], y=x_mask,
    steps_per_epoch=len(df_train) / batchSIZE,
    #steps_per_epoch=len(dataset_train) / batchSIZE,
    validation_data=val,
    validation_steps=len(df_val) / batchSIZE,
	epochs=30, batch_size=batchSIZE)

fig = plt.figure(figsize = plt.figaspect(0.3))
fig.suptitle("Loss and accuracy for CNN-MLP model")
        
ax = fig.add_subplot(1,2,1)
ax.plot(hist.history['loss'], label='Train loss')
ax.plot(hist.history['val_loss'], label = 'Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()


ax = fig.add_subplot(1,2,2)
ax.plot(hist.history['accuracy'], label='Train accuracy')
ax.plot(hist.history['val_accuracy'], label = 'Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


plt.show()
# Out:
# [INFO] training model...
# Epoch 1/30
# 2023-05-26 15:46:04.592405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 56/56 [==============================] - ETA: 0s - loss: 1.5245 - accuracy: 0.1667
# 2023-05-26 15:46:58.856490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [43,2]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-26 15:46:58.891522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 56/56 [==============================] - 56s 975ms/step - loss: 1.5245 - accuracy: 0.1667 - val_loss: 1.4228 - val_accuracy: 0.2093
# Epoch 2/30
# 56/56 [==============================] - 54s 971ms/step - loss: 1.4103 - accuracy: 0.1726 - val_loss: 1.3817 - val_accuracy: 0.2093
# Epoch 3/30
# 56/56 [==============================] - 54s 968ms/step - loss: 1.3775 - accuracy: 0.3155 - val_loss: 1.3588 - val_accuracy: 0.2791
# Epoch 4/30
# 56/56 [==============================] - 54s 969ms/step - loss: 1.3582 - accuracy: 0.3810 - val_loss: 1.3237 - val_accuracy: 0.3721
# Epoch 5/30
# 56/56 [==============================] - 54s 968ms/step - loss: 1.3277 - accuracy: 0.4226 - val_loss: 1.3183 - val_accuracy: 0.3953
# Epoch 6/30
# 56/56 [==============================] - 54s 968ms/step - loss: 1.3176 - accuracy: 0.4405 - val_loss: 1.3128 - val_accuracy: 0.3953
# Epoch 7/30
# 56/56 [==============================] - 54s 969ms/step - loss: 1.3132 - accuracy: 0.4405 - val_loss: 1.3141 - val_accuracy: 0.3953
# Epoch 8/30
# 56/56 [==============================] - 54s 968ms/step - loss: 1.3077 - accuracy: 0.4405 - val_loss: 1.3163 - val_accuracy: 0.3953
# Epoch 9/30
# 56/56 [==============================] - 54s 971ms/step - loss: 1.3044 - accuracy: 0.4405 - val_loss: 1.3184 - val_accuracy: 0.3953
# Epoch 10/30
# 56/56 [==============================] - 54s 971ms/step - loss: 1.3027 - accuracy: 0.4405 - val_loss: 1.3196 - val_accuracy: 0.3953
# Epoch 11/30
# 56/56 [==============================] - 54s 970ms/step - loss: 1.3026 - accuracy: 0.4405 - val_loss: 1.3231 - val_accuracy: 0.3953
